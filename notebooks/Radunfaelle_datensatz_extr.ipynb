# %%
print ('Aus dem Datensatz: Straßenverkehrsunfälle nach Unfallort in Berlin 2021' + "\n")
print ("Zeitperiode: vom 01.01.2021 bis 31.12.2021" + "\n")
print ("EINLESEN DATEN" + "\n")
import pandas as pd

#Lesen der CSV
datei_pfad = 'AfSBBB_BE_LOR_Strasse_Strassenverkehrsunfaelle_2021_Datensatz_2.csv'
df = pd.read_csv(datei_pfad)

#Ausgabe, ersten 5 zeilen
#print(df.head())
df.head()
# Out:
# Aus dem Datensatz: Straßenverkehrsunfälle nach Unfallort in Berlin 2021
#
# Zeitperiode: vom 01.01.2021 bis 31.12.2021
#
# EINLESEN DATEN
#                                                                                     OBJECTID;LAND;BEZ;LOR_ab_2021;UJAHR;UMONAT;USTUNDE;UWOCHENTAG;UKATEGORIE;UART;UTYP1;ULICHTVERH;IstRad;IstPKW;IstFuss;IstKrad;IstGkfz;IstSonstige;USTRZUSTAND;LINREFX;LINREFY;XGCSWGS84;YGCSWGS84
# 219249;11;3;3701658;2021;11;18;2;3;0;3;2;0;1;0;... 0742;5829640 204;13 42689483;52                                         53393955.0
# 219248;11;7;7501134;2021;12;19;7;3;6;2;2;0;1;1;... 5317;5819049 219;13 39209027;52                                         43995086.0
# 219247;11;4;4100101;2021;12;17;4;3;5;2;2;0;1;0;... 6128;5829680 195;13 32624193;52                                         53802784.0
# 219246;11;4;4501041;2021;12;15;7;3;5;2;1;0;1;0;... 0395;5825362 081;13 31652064;52                                         49953417.0
# ...

# %%
print ("AUSGABE TABELLE")
#sep: Bestimmt das Trennzeichen. simikolen wird nicht korrekt gelesen. Daher hier ändern:
df = pd.read_csv(datei_pfad,sep=";")
df
# Out:
# AUSGABE TABELLE
#        OBJECTID  LAND  BEZ  LOR_ab_2021  UJAHR  UMONAT  USTUNDE  UWOCHENTAG  \
# 0        219249    11    3    3701658.0   2021      11       18           2
# 1        219248    11    7    7501134.0   2021      12       19           7
# 2        219247    11    4    4100101.0   2021      12       17           4
# 3        219246    11    4    4501041.0   2021      12       15           7
# 4        219243    11   11   11501339.0   2021      12        9           5
# ...         ...   ...  ...          ...    ...     ...      ...         ...
# 11262    112174    11    4    4300414.0   2021       3       16           4
# 11263    111541    11    4    4400726.0   2021       1        1           6
# 11264    110370    11    3    2400520.0   2021       1       20           1
# 11265    109998    11    7    7300619.0   2021       1       14           7
# 11266    109753    11   12   12400723.0   2021       1       14           2
#
# ...

# %%
print ("AUSGABE TABELLE - SPALTEN DER ISTRAD UND KOORDINATEN - Format der Koordinaten müssen umgerechnet werden")
# Extrahieren der Spalte 'IstRad'
#extr_spalte = df['IstRad', 'LINREFX', 'LINREFY']

# Ausgabe der extrahierten Spalte
#extr_spalte

datei_pfad = 'AfSBBB_BE_LOR_Strasse_Strassenverkehrsunfaelle_2021_Datensatz_2.csv'
df = pd.read_csv(datei_pfad, sep=";", decimal=",", usecols=["IstRad","LINREFX","LINREFY"])
df
# Out:
# AUSGABE TABELLE - SPALTEN DER ISTRAD UND KOORDINATEN - Format der Koordinaten müssen umgerechnet werden
#        IstRad      LINREFX      LINREFY
# 0           0  800202.0742  5829640.204
# 1           0  798479.5317  5819049.219
# 2           0  793352.6128  5829680.195
# 3           0  792950.0395  5825362.081
# 4           0  807182.0100  5825602.793
# ...       ...          ...          ...
# 11262       0  791505.4105  5826555.664
# 11263       0  791154.6790  5824616.757
# 11264       0  799988.2122  5828912.431
# 11265       0  796018.2589  5822739.196
# 11266       0  791884.0985  5839010.713
#
# [11267 rows x 3 columns]

# %%
print ("AUSGABE TABELLE - SPALTEN:ISTRAD, UNFÄLLE MIT RADBETEILIGUNG (1) UND DEREN KOORDINATEN")
#zeilen von IstRad mit 1 = Unfall mit Radbeteiligung ausgeben
rad = df[df['IstRad'] == 1]
rad

#df.loc[df["IstRad"] == 1]
# Out:
# AUSGABE TABELLE - SPALTEN:ISTRAD, UNFÄLLE MIT RADBETEILIGUNG (1) UND DEREN KOORDINATEN
#        IstRad      LINREFX      LINREFY
# 18          1  792439.7595  5824095.448
# 24          1  796973.1702  5826579.744
# 38          1  783320.2118  5830271.905
# 40          1  799021.6282  5828725.878
# 41          1  801364.4615  5829700.555
# ...       ...          ...          ...
# 11245       1  802141.8982  5827763.741
# 11251       1  797513.4757  5818141.142
# 11257       1  812566.7795  5827181.034
# 11258       1  802664.0378  5825207.751
# 11260       1  797898.6687  5825137.375
#
# [4251 rows x 3 columns]

# %%
pip install pandas matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print ("PLOT DER KOORDINATEN - Unfälle mit Radbeteiligung")
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(df['LINREFX'], df['LINREFY'], c='red', marker='.')

#for i, row in df.iterrows():
#    plt.text(row['Laengengrad'] + 0.02, row['Breitengrad'] + 0.02, row['Stadt'], fontsize=9)

plt.xlabel('Längengrad')
plt.ylabel('Breitengrad')
plt.title('Plot der Koordinaten')

plt.grid(True)
plt.show()
# Out:
# PLOT DER KOORDINATEN - Unfälle mit Radbeteiligung
